# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = {
    'Names':['ajay','sidd','sachin','nikita','rajvendra','ankush'],
    'Age' : [21,22,23,43,45,56],
    'Gender':['male','male','male','female','female','male'],
    'Maths':[34,54,65,67,87,88],
    'Phy':[65,67,45,67,87,88]
}

# %%
df
# Out:
# {'Names': ['ajay', 'sidd', 'sachin', 'nikita', 'rajvendra', 'ankush'],
#  'Age': [21, 22, 23, 43, 45, 56],
#  'Gender': ['male', 'male', 'male', 'female', 'female', 'male'],
#  'Maths': [34, 54, 65, 67, 87, 88],
#  'Phy': [65, 67, 45, 67, 87, 88]}

# %%
df =  pd.DataFrame(df)

# %%
df
# Out:
#        Names  Age  Gender  Maths  Phy
# 0       ajay   21    male     34   65
# 1       sidd   22    male     54   67
# 2     sachin   23    male     65   45
# 3     nikita   43  female     67   67
# 4  rajvendra   45  female     87   87
# 5     ankush   56    male     88   88

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
# Names     6 non-null object
# Age       6 non-null int64
# Gender    6 non-null object
# Maths     6 non-null int64
# Phy       6 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 320.0+ bytes

# %%
df['Names']
# Out:
# 0         ajay
# 1         sidd
# 2       sachin
# 3       nikita
# 4    rajvendra
# 5       ankush
# Name: Names, dtype: object

# %%
df['Maths'][5]
# Out:
# 88

# %%
df['Total']  = df['Maths'] + df['Phy']

# %%
df.head(3)
# Out:
#     Names  Age Gender  Maths  Phy  Total
# 0    ajay   21   male     34   65     99
# 1    sidd   22   male     54   67    121
# 2  sachin   23   male     65   45    110

# %%
df.tail(3)
# Out:
#        Names  Age  Gender  Maths  Phy  Total
# 3     nikita   43  female     67   67    134
# 4  rajvendra   45  female     87   87    174
# 5     ankush   56    male     88   88    176

# %%
tf = pd.DataFrame({
    'A': np.random.randint(1,100,10),
    'B': np.random.randint(1,50,10),
    'C': np.random.randint(1,60,10)
})

# %%
tf.head()
# Out:
#     A   B   C
# 0  95  24  19
# 1  84  36  14
# 2  71  34  12
# 3  62  47  21
# 4   3  13  11

# %%
tf.columns = ['one','two','three']

# %%
tf.head()
# Out:
#    one  two  three
# 0   95   24     19
# 1   84   36     14
# 2   71   34     12
# 3   62   47     21
# 4    3   13     11

# %%
tf = tf.rename(columns={'one':'on','two':'tw','three':'th'})

# %%
tf.head()
# Out:
#    on  tw  th
# 0  95  24  19
# 1  84  36  14
# 2  71  34  12
# 3  62  47  21
# 4   3  13  11

# %%
len(tf)
# Out:
# 10

# %%
tf.shape
# Out:
# (10, 3)

# %%
tf.size
# Out:
# 30

# %%
date = pd.date_range('20191121',periods=10)    #to create a date

# %%
len(date)
# Out:
# 10

# %%
tf.index = date

# %%
tf.head()
# Out:
#             on  tw  th
# 2019-11-21  95  24  19
# 2019-11-22  84  36  14
# 2019-11-23  71  34  12
# 2019-11-24  62  47  21
# 2019-11-25   3  13  11

# %%
tf.head()
# Out:
#             on  tw  th
# 2019-11-21  95  24  19
# 2019-11-22  84  36  14
# 2019-11-23  71  34  12
# 2019-11-24  62  47  21
# 2019-11-25   3  13  11

# %%
plt.figure(figsize=(10,5))
plt.plot(tf)
plt.ylim(0,100)
plt.show()

# %%
dff = pd.DataFrame(np.random.random(100).reshape(-1,5),columns=list('ABCDE'),index=range(1,21))

# %%
dff
# Out:
#            A         B         C         D         E
# 1   0.798271  0.423119  0.639648  0.712793  0.047607
# 2   0.110323  0.371279  0.911216  0.716387  0.141375
# 3   0.933572  0.612100  0.137616  0.620790  0.272423
# 4   0.445782  0.837398  0.272495  0.256546  0.853111
# 5   0.244537  0.999927  0.874221  0.662247  0.445700
# 6   0.674846  0.884440  0.503471  0.005554  0.130329
# 7   0.633437  0.824638  0.183820  0.005129  0.583048
# 8   0.170059  0.270475  0.720329  0.429438  0.082571
# 9   0.259522  0.262263  0.634984  0.873667  0.610552
# 10  0.307028  0.840450  0.061894  0.346037  0.202345
# 11  0.990804  0.616111  0.664103  0.090754  0.399936
# 12  0.485120  0.741130  0.600017  0.792313  0.729263
# 13  0.573056  0.051768  0.591663  0.498559  0.630575
# 14  0.654489  0.224402  0.634352  0.086788  0.431234
# 15  0.972284  0.337023  0.732291  0.676366  0.756807
# 16  0.381670  0.455229  0.381741  0.899835  0.256387
# 17  0.170233  0.734347  0.445803  0.450719  0.763985
# ...

# %%
data = [['siddd',8394483943],
       ['ajay',93489438394],
       ['sachin',4893844394],
       ['ankush',9304394434],
       ['vipul',43948839443],
       ['nidhi',9943340943],]

column = ['Names','Phone']
index = ['a','b','c','d','e','f']

# %%
data = pd.DataFrame(data,columns=column,index=index)

# %%
data
# Out:
#     Names        Phone
# a   siddd   8394483943
# b    ajay  93489438394
# c  sachin   4893844394
# d  ankush   9304394434
# e   vipul  43948839443
# f   nidhi   9943340943

# %%
data['gender'] = ['male','male','male','male','male','female']

# %%
data
# Out:
#     Names        Phone  gender
# a   siddd   8394483943    male
# b    ajay  93489438394    male
# c  sachin   4893844394    male
# d  ankush   9304394434    male
# e   vipul  43948839443    male
# f   nidhi   9943340943  female

# %%
dat= [1,2,3,4,5,6]

# %%
data.drop('mycol',axis=1,inplace=True)

# %%
data.insert(1,'mycol',dat)   # to insert a column at particular place

# %%
data
# Out:
#     Names  mycol        Phone  gender
# a   siddd      1   8394483943    male
# b    ajay      2  93489438394    male
# c  sachin      3   4893844394    male
# d  ankush      4   9304394434    male
# e   vipul      5  43948839443    male
# f   nidhi      6   9943340943  female

# %%
data.gender.value_counts().plot(kind='bar',color=['r','g'])
plt.show()

# %%
data['mycol']=data['mycol'].apply(lambda x : x**2)

# %%
data.head()
# Out:
#     Names  mycol        Phone gender
# a   siddd      1   8394483943   male
# b    ajay      4  93489438394   male
# c  sachin      9   4893844394   male
# d  ankush     16   9304394434   male
# e   vipul     25  43948839443   male

# %%
df.describe()
# Out:
#              Age      Maths        Phy       Total
# count   6.000000   6.000000   6.000000    6.000000
# mean   35.000000  65.833333  69.833333  135.666667
# std    14.926487  20.468675  16.005207   32.610837
# min    21.000000  34.000000  45.000000   99.000000
# 25%    22.250000  56.750000  65.500000  112.750000
# 50%    33.000000  66.000000  67.000000  127.500000
# 75%    44.500000  82.000000  82.000000  164.000000
# max    56.000000  88.000000  88.000000  176.000000

# %%
df.columns = [var.lower() for var in df.columns]

# %%
df.head()
# Out:
#        names  age  gender  maths  phy  total
# 0       ajay   21    male     34   65     99
# 1       sidd   22    male     54   67    121
# 2     sachin   23    male     65   45    110
# 3     nikita   43  female     67   67    134
# 4  rajvendra   45  female     87   87    174

# %%
df[df.gender== 'male']
# Out:
#     names  age gender  maths  phy  total
# 0    ajay   21   male     34   65     99
# 1    sidd   22   male     54   67    121
# 2  sachin   23   male     65   45    110
# 5  ankush   56   male     88   88    176

# %%
df.where(df.gender=='male')
# Out:
#     names   age gender  maths   phy  total
# 0    ajay  21.0   male   34.0  65.0   99.0
# 1    sidd  22.0   male   54.0  67.0  121.0
# 2  sachin  23.0   male   65.0  45.0  110.0
# 3     NaN   NaN    NaN    NaN   NaN    NaN
# 4     NaN   NaN    NaN    NaN   NaN    NaN
# 5  ankush  56.0   male   88.0  88.0  176.0

# %%
# Out:
#        names  age  gender  maths  phy  total
# 0       ajay   21    male     34   65     99
# 1       sidd   22    male     54   67    121
# 2     sachin   23    male     65   45    110
# 3     nikita   43  female     67   67    134
# 4  rajvendra   45  female     87   87    174
# 5     ankush   56    male     88   88    176

# %%
df1  = {
    'names':['shubham','kushal',np.nan,'keyur'],
    'age':[54,np.nan,45,np.nan],
    'gender':['male','male',np.nan,'male'],
    'maths':[43,55,65,67],
    'phy' :[56,79,68,55],
    'total':[99,134,133,122]
}

# %%
df1 = pd.DataFrame(df1)

# %%
df1
# Out:
#      names   age gender  maths  phy  total
# 0  shubham  54.0   male     43   56     99
# 1   kushal   NaN   male     55   79    134
# 2      NaN  45.0    NaN     65   68    133
# 3    keyur   NaN   male     67   55    122

# %%
df
# Out:
#        names  age  gender  maths  phy  total
# 0       ajay   21    male     34   65     99
# 1       sidd   22    male     54   67    121
# 2     sachin   23    male     65   45    110
# 3     nikita   43  female     67   67    134
# 4  rajvendra   45  female     87   87    174
# 5     ankush   56    male     88   88    176

# %%
df = df.append(df1,ignore_index=True)

# %%
df.head()
# Out:
#        names   age  gender  maths  phy  total
# 0       ajay  21.0    male     34   65     99
# 1       sidd  22.0    male     54   67    121
# 2     sachin  23.0    male     65   45    110
# 3     nikita  43.0  female     67   67    134
# 4  rajvendra  45.0  female     87   87    174

# %%
df.tail()
# Out:
#      names   age gender  maths  phy  total
# 5   ankush  56.0   male     88   88    176
# 6  shubham  54.0   male     43   56     99
# 7   kushal   NaN   male     55   79    134
# 8      NaN  45.0    NaN     65   68    133
# 9    keyur   NaN   male     67   55    122

# %%
df.dropna()
# Out:
#        names   age  gender  maths  phy  total
# 0       ajay  21.0    male     34   65     99
# 1       sidd  22.0    male     54   67    121
# 2     sachin  23.0    male     65   45    110
# 3     nikita  43.0  female     67   67    134
# 4  rajvendra  45.0  female     87   87    174
# 5     ankush  56.0    male     88   88    176
# 6    shubham  54.0    male     43   56     99

# %%
df.fillna(np.mean(df),inplace=True)

# %%
df.loc[8]['names'] = 'vaishali'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.tail()
# Out:
#      names     age gender  maths  phy  total
# 5   ankush  56.000   male     88   88    176
# 6  shubham  54.000   male     43   56     99
# 7   kushal  38.625   male     55   79    134
# 8      NaN  45.000    NaN     65   68    133
# 9    keyur  38.625   male     67   55    122

# %%
df.iat[8,0] = 'vaishali'

# %%
df
# Out:
#        names     age  gender  maths  phy  total
# 0       ajay  21.000    male     34   65     99
# 1       sidd  22.000    male     54   67    121
# 2     sachin  23.000    male     65   45    110
# 3     nikita  43.000  female     67   67    134
# 4  rajvendra  45.000  female     87   87    174
# 5     ankush  56.000    male     88   88    176
# 6    shubham  54.000    male     43   56     99
# 7     kushal  38.625    male     55   79    134
# 8   vaishali  45.000     NaN     65   68    133
# 9      keyur  38.625    male     67   55    122

# %%
df.iat[8,2] = 'female'

# %%
df.tail()
# Out:
#       names     age  gender  maths  phy  total
# 5    ankush  56.000    male     88   88    176
# 6   shubham  54.000    male     43   56     99
# 7    kushal  38.625    male     55   79    134
# 8  vaishali  45.000  female     65   68    133
# 9     keyur  38.625    male     67   55    122

# %%
df.isna()
# Out:
#    names    age  gender  maths    phy  total
# 0  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 3  False  False   False  False  False  False
# 4  False  False   False  False  False  False
# 5  False  False   False  False  False  False
# 6  False  False   False  False  False  False
# 7  False  False   False  False  False  False
# 8  False  False   False  False  False  False
# 9  False  False   False  False  False  False

# %%
np.random.random(40).reshape(4,10)
# Out:
# array([[0.93466914, 0.98812504, 0.85262097, 0.33289386, 0.70744387,
#         0.48930578, 0.41374293, 0.63503831, 0.27128069, 0.46763033],
#        [0.50047055, 0.99861443, 0.29858962, 0.50690625, 0.4636529 ,
#         0.62366867, 0.75524791, 0.58543421, 0.23926455, 0.39682228],
#        [0.71271812, 0.79597272, 0.08551283, 0.49360531, 0.52957881,
#         0.01859188, 0.21614532, 0.93751205, 0.53385326, 0.46197047],
#        [0.94510569, 0.30543192, 0.31580331, 0.58173045, 0.96163591,
#         0.27734785, 0.55853935, 0.84450545, 0.36969346, 0.4640386 ]])

# %%
df = pd.DataFrame({
    'one': np.random.randint(1,100,100),
    'two': np.random.randint(1,200,100),
    'three':np.random.randint(1,300,100)
})

# %%
df.head()
# Out:
#    one  two  three
# 0   36  159    290
# 1   29   41    169
# 2   21  128     51
# 3   66   21    193
# 4   21  192    241

# %%
plt.figure(figsize=(10,5),facecolor='#800080')
plt.plot(df)
plt.show()

# %%
e = df[1:10]

# %%
f = df[11:24]
g = df[30:50]

# %%
ndf = pd.concat([e,f,g])

# %%
ndf.head()
# Out:
#    one  two  three
# 1   29   41    169
# 2   21  128     51
# 3   66   21    193
# 4   21  192    241
# 5   47  135    222

# %%
ndf.columns = [var.upper() for var in df.columns]

# %%
ndf.head()
# Out:
#    ONE  TWO  THREE
# 1   29   41    169
# 2   21  128     51
# 3   66   21    193
# 4   21  192    241
# 5   47  135    222

# %%
ndf['Total'] = ndf['ONE'] + ndf['TWO'] + ndf['THREE']

# %%
ndf.head()
# Out:
#    ONE  TWO  THREE  Total
# 1   29   41    169    239
# 2   21  128     51    200
# 3   66   21    193    280
# 4   21  192    241    454
# 5   47  135    222    404

# %%
ndf.sort_values('ONE',inplace=True)

# %%
ndf.reset_index(inplace=True)

# %%
ndf.drop('index',axis=1,inplace=True)

# %%
ndf.head()
# Out:
#    ONE  TWO  THREE  Total
# 0    4  132     26    162
# 1   11   76    268    355
# 2   19  123     24    166
# 3   21  128     51    200
# 4   21  192    241    454

# %%
ndf.ONE.value_counts()
# Out:
# 61    3
# 63    2
# 71    2
# 21    2
# 39    2
# 26    2
# 24    2
# 53    2
# 55    2
# 72    1
# 4     1
# 11    1
# 83    1
# 77    1
# 19    1
# 66    1
# 86    1
# 73    1
# 29    1
# 92    1
# 62    1
# 95    1
# 97    1
# 93    1
# 36    1
# 38    1
# 41    1
# 44    1
# 47    1
# 54    1
# 57    1
# 64    1
# Name: ONE, dtype: int64

# %%
ndf.ONE.count()
# Out:
# 42

# %%
ndf.ONE.unique()
# Out:
# array([ 4, 11, 19, 21, 24, 26, 29, 36, 38, 39, 41, 44, 47, 53, 54, 55, 57,
#        61, 62, 63, 64, 66, 71, 72, 73, 77, 83, 86, 92, 93, 95, 97],
#       dtype=int64)

# %%
ndf.ONE.nunique()
# Out:
# 32
